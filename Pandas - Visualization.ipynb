# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'E:\Study\Pandas/Ice Cream Ratings.csv')
df.set_index('Date',inplace=True)
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df.plot(kind='line',subplots=True,xlabel='Dates',ylabel='Rating',title='Rating Charts')
# Out:
# array([<Axes: xlabel='Dates', ylabel='Rating'>,
#        <Axes: xlabel='Dates', ylabel='Rating'>,
#        <Axes: xlabel='Dates', ylabel='Rating'>], dtype=object)

# %%
df['Flavor Rating'].plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind='barh',stacked=True)
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot(kind='scatter',x='Texture Rating',y='Flavor Rating',s=400,c='green')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Flavor Rating'>

# %%
df.plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot(kind='area',figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind='pie',y='Flavor Rating',figsize=(10,10))
# Out:
# <Axes: ylabel='Flavor Rating'>
